# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# Import pandas and read the charity_data.csv from the provided cloud URL.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-92ee6ac84881> in <cell line: 0>()
#       1 # Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
# ----> 2 application_df = application_df.drop(columns=['EIN', 'NAME'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['EIN', 'NAME'] not found in axis"

# %%
# Determine the number of unique values in each column.
unique_counts = application_df.nunique()
unique_counts
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
application_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
threshold = 10
application_types_to_replace = application_type_counts[application_type_counts < threshold].index.tolist()
application_types_to_replace

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# T12         27
# T2          16
# Other       11
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_types_to_replace = classification_counts[classification_counts <= 1].index.tolist()
classification_types_to_replace
# Out:
# ['C2190',
#  'C4200',
#  'C2600',
#  'C5200',
#  'C1370',
#  'C1248',
#  'C6100',
#  'C1820',
#  'C1900',
#  'C1236',
#  'C3700',
#  'C2570',
#  'C1580',
#  'C1245',
#  'C2500',
#  'C1570',
#  'C1283',
#  'C2380',
#  'C1732',
#  'C1728',
#  'C2170',
#  'C4120',
#  'C8210',
#  'C2561',
#  'C4500',
#  'C2150']

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
threshold = 1
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = classification_counts[classification_counts < threshold].index.tolist()
classifications_to_replace

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# pd.get_dummies(application_df, columns=['INCOME_AMT'])

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df, columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS','IS_SUCCESSFUL'], drop_first=True)
application_df.head()
# Out:
#    ASK_AMT  APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  \
# 0     5000                  True                 False                 False
# 1   108590                 False                 False                 False
# 2     5000                 False                 False                 False
# 3     6692                 False                 False                 False
# 4   142590                 False                 False                 False
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T2  APPLICATION_TYPE_T3  \
# 0                 False                False                False
# 1                 False                False                 True
# 2                 False                False                False
# 3                 False                False                 True
# 4                 False                False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_Y  \
# 0            False              False                     False
# 1            False              False                     False
# 2            False              False                     False
# 3            False              False                     False
# 4            False              False                     False
#
#    IS_SUCCESSFUL_1
# 0             True
# 1             True
# 2            False
# 3             True
# 4             True
#
# [5 rows x 106 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL_1']  # The target column
X = application_df.drop(columns=['IS_SUCCESSFUL_1'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=78)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (27439, 105)
# X_test shape: (6860, 105)
# y_train shape: (27439,)
# y_test shape: (6860,)

# %%
X_train.dtypes

for x in X_train.dtypes:
    if not x == "bool":
        print(x)
# Out:
# int64

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=128, input_dim=X_train_scaled.shape[1], activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=64, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │          13,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 21,889 (85.50 KB)
#  Trainable params: 21,889 (85.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = nn.fit(X_train_scaled, y_train, epochs=100, batch_size=32,
                 validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7042 - loss: 0.5891 - val_accuracy: 0.7172 - val_loss: 0.5668
# Epoch 2/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7295 - loss: 0.5573 - val_accuracy: 0.7176 - val_loss: 0.5630
# Epoch 3/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7354 - loss: 0.5480 - val_accuracy: 0.7229 - val_loss: 0.5596
# Epoch 4/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7353 - loss: 0.5475 - val_accuracy: 0.7191 - val_loss: 0.5576
# Epoch 5/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7324 - loss: 0.5460 - val_accuracy: 0.7243 - val_loss: 0.5559
# Epoch 6/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7362 - loss: 0.5445 - val_accuracy: 0.7227 - val_loss: 0.5585
# Epoch 7/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7365 - loss: 0.5400 - val_accuracy: 0.7226 - val_loss: 0.5572
# Epoch 8/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7338 - loss: 0.5435 - val_accuracy: 0.7243 - val_loss: 0.5577
# Epoch 9/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7352 - loss: 0.5427 - val_accuracy: 0.7238 - val_loss: 0.5567
# Epoch 10/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7309 - loss: 0.5457 - val_accuracy: 0.7229 - val_loss: 0.5611
# Epoch 11/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7373 - loss: 0.5404 - val_accuracy: 0.7236 - val_loss: 0.5562
# Epoch 12/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7376 - loss: 0.5422 - val_accuracy: 0.7243 - val_loss: 0.5547
# Epoch 13/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7408 - loss: 0.5419 - val_accuracy: 0.7254 - val_loss: 0.5562
# Epoch 14/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7394 - loss: 0.5381 - val_accuracy: 0.7242 - val_loss: 0.5557
# Epoch 15/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7331 - loss: 0.5466 - val_accuracy: 0.7242 - val_loss: 0.5575
# Epoch 16/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7383 - loss: 0.5361 - val_accuracy: 0.7235 - val_loss: 0.5584
# Epoch 17/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7416 - loss: 0.5351 - val_accuracy: 0.7264 - val_loss: 0.5567
# Epoch 18/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7376 - loss: 0.5408 - val_accuracy: 0.7257 - val_loss: 0.5551
# Epoch 19/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7361 - loss: 0.5432 - val_accuracy: 0.7246 - val_loss: 0.5595
# Epoch 20/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7378 - loss: 0.5375 - val_accuracy: 0.7242 - val_loss: 0.5597
# Epoch 21/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7445 - loss: 0.5329 - val_accuracy: 0.7239 - val_loss: 0.5574
# Epoch 22/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7438 - loss: 0.5334 - val_accuracy: 0.7248 - val_loss: 0.5556
# Epoch 23/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7381 - loss: 0.5375 - val_accuracy: 0.7241 - val_loss: 0.5597
# Epoch 24/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7336 - loss: 0.5420 - val_accuracy: 0.7246 - val_loss: 0.5592
# Epoch 25/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7389 - loss: 0.5359 - val_accuracy: 0.7258 - val_loss: 0.5573
# Epoch 26/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7418 - loss: 0.5361 - val_accuracy: 0.7251 - val_loss: 0.5582
# Epoch 27/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7391 - loss: 0.5368 - val_accuracy: 0.7262 - val_loss: 0.5568
# Epoch 28/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7447 - loss: 0.5293 - val_accuracy: 0.7248 - val_loss: 0.5588
# Epoch 29/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7382 - loss: 0.5381 - val_accuracy: 0.7243 - val_loss: 0.5586
# Epoch 30/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7388 - loss: 0.5345 - val_accuracy: 0.7248 - val_loss: 0.5610
# Epoch 31/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7439 - loss: 0.5317 - val_accuracy: 0.7255 - val_loss: 0.5568
# Epoch 32/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7448 - loss: 0.5307 - val_accuracy: 0.7249 - val_loss: 0.5571
# Epoch 33/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7438 - loss: 0.5331 - val_accuracy: 0.7255 - val_loss: 0.5613
# Epoch 34/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7432 - loss: 0.5318 - val_accuracy: 0.7248 - val_loss: 0.5583
# Epoch 35/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7354 - loss: 0.5398 - val_accuracy: 0.7248 - val_loss: 0.5594
# Epoch 36/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7416 - loss: 0.5347 - val_accuracy: 0.7262 - val_loss: 0.5593
# Epoch 37/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7460 - loss: 0.5304 - val_accuracy: 0.7248 - val_loss: 0.5568
# Epoch 38/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7409 - loss: 0.5345 - val_accuracy: 0.7248 - val_loss: 0.5680
# Epoch 39/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7398 - loss: 0.5331 - val_accuracy: 0.7246 - val_loss: 0.5606
# Epoch 40/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7462 - loss: 0.5281 - val_accuracy: 0.7243 - val_loss: 0.5615
# Epoch 41/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7431 - loss: 0.5335 - val_accuracy: 0.7257 - val_loss: 0.5586
# Epoch 42/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7448 - loss: 0.5344 - val_accuracy: 0.7243 - val_loss: 0.5625
# Epoch 43/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7396 - loss: 0.5372 - val_accuracy: 0.7252 - val_loss: 0.5601
# Epoch 44/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7402 - loss: 0.5358 - val_accuracy: 0.7246 - val_loss: 0.5629
# Epoch 45/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7430 - loss: 0.5321 - val_accuracy: 0.7233 - val_loss: 0.5584
# Epoch 46/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7413 - loss: 0.5342 - val_accuracy: 0.7233 - val_loss: 0.5623
# Epoch 47/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7416 - loss: 0.5328 - val_accuracy: 0.7235 - val_loss: 0.5592
# Epoch 48/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7420 - loss: 0.5313 - val_accuracy: 0.7243 - val_loss: 0.5595
# Epoch 49/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7454 - loss: 0.5301 - val_accuracy: 0.7232 - val_loss: 0.5604
# Epoch 50/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7425 - loss: 0.5330 - val_accuracy: 0.7242 - val_loss: 0.5592
# Epoch 51/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7413 - loss: 0.5332 - val_accuracy: 0.7251 - val_loss: 0.5623
# Epoch 52/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7428 - loss: 0.5318 - val_accuracy: 0.7242 - val_loss: 0.5601
# Epoch 53/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7400 - loss: 0.5332 - val_accuracy: 0.7267 - val_loss: 0.5585
# Epoch 54/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7446 - loss: 0.5299 - val_accuracy: 0.7243 - val_loss: 0.5607
# Epoch 55/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7411 - loss: 0.5351 - val_accuracy: 0.7252 - val_loss: 0.5624
# Epoch 56/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7420 - loss: 0.5323 - val_accuracy: 0.7248 - val_loss: 0.5711
# Epoch 57/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7415 - loss: 0.5314 - val_accuracy: 0.7229 - val_loss: 0.5689
# Epoch 58/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7404 - loss: 0.5288 - val_accuracy: 0.7238 - val_loss: 0.5671
# Epoch 59/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7442 - loss: 0.5304 - val_accuracy: 0.7249 - val_loss: 0.5648
# Epoch 60/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7410 - loss: 0.5316 - val_accuracy: 0.7245 - val_loss: 0.5620
# Epoch 61/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7401 - loss: 0.5324 - val_accuracy: 0.7246 - val_loss: 0.5637
# Epoch 62/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7455 - loss: 0.5257 - val_accuracy: 0.7261 - val_loss: 0.5650
# Epoch 63/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7421 - loss: 0.5290 - val_accuracy: 0.7245 - val_loss: 0.5659
# Epoch 64/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7432 - loss: 0.5246 - val_accuracy: 0.7243 - val_loss: 0.5624
# Epoch 65/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7386 - loss: 0.5357 - val_accuracy: 0.7252 - val_loss: 0.5639
# Epoch 66/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7471 - loss: 0.5237 - val_accuracy: 0.7243 - val_loss: 0.5674
# Epoch 67/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7458 - loss: 0.5281 - val_accuracy: 0.7245 - val_loss: 0.5621
# Epoch 68/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7442 - loss: 0.5308 - val_accuracy: 0.7241 - val_loss: 0.5694
# Epoch 69/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7440 - loss: 0.5281 - val_accuracy: 0.7255 - val_loss: 0.5696
# Epoch 70/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7435 - loss: 0.5282 - val_accuracy: 0.7219 - val_loss: 0.5775
# Epoch 71/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7460 - loss: 0.5260 - val_accuracy: 0.7248 - val_loss: 0.5662
# Epoch 72/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7473 - loss: 0.5242 - val_accuracy: 0.7239 - val_loss: 0.5668
# Epoch 73/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7405 - loss: 0.5312 - val_accuracy: 0.7243 - val_loss: 0.5739
# Epoch 74/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7412 - loss: 0.5293 - val_accuracy: 0.7239 - val_loss: 0.5696
# Epoch 75/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7452 - loss: 0.5280 - val_accuracy: 0.7261 - val_loss: 0.5677
# Epoch 76/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7444 - loss: 0.5333 - val_accuracy: 0.7255 - val_loss: 0.5670
# Epoch 77/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7434 - loss: 0.5282 - val_accuracy: 0.7248 - val_loss: 0.5720
# Epoch 78/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7446 - loss: 0.5283 - val_accuracy: 0.7249 - val_loss: 0.5744
# Epoch 79/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7433 - loss: 0.5301 - val_accuracy: 0.7242 - val_loss: 0.5732
# Epoch 80/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7454 - loss: 0.5270 - val_accuracy: 0.7258 - val_loss: 0.5692
# Epoch 81/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7439 - loss: 0.5298 - val_accuracy: 0.7257 - val_loss: 0.5759
# Epoch 82/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7474 - loss: 0.5239 - val_accuracy: 0.7243 - val_loss: 0.5699
# Epoch 83/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7433 - loss: 0.5296 - val_accuracy: 0.7246 - val_loss: 0.5727
# Epoch 84/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7408 - loss: 0.5295 - val_accuracy: 0.7258 - val_loss: 0.5794
# Epoch 85/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7477 - loss: 0.5255 - val_accuracy: 0.7249 - val_loss: 0.5743
# Epoch 86/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7455 - loss: 0.5258 - val_accuracy: 0.7227 - val_loss: 0.5758
# Epoch 87/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7412 - loss: 0.5313 - val_accuracy: 0.7238 - val_loss: 0.5742
# Epoch 88/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7462 - loss: 0.5270 - val_accuracy: 0.7257 - val_loss: 0.5821
# Epoch 89/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7410 - loss: 0.5289 - val_accuracy: 0.7255 - val_loss: 0.5762
# Epoch 90/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7434 - loss: 0.5289 - val_accuracy: 0.7245 - val_loss: 0.5802
# Epoch 91/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7459 - loss: 0.5278 - val_accuracy: 0.7239 - val_loss: 0.5826
# Epoch 92/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7422 - loss: 0.5290 - val_accuracy: 0.7258 - val_loss: 0.5843
# Epoch 93/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7507 - loss: 0.5217 - val_accuracy: 0.7245 - val_loss: 0.5794
# Epoch 94/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7470 - loss: 0.5270 - val_accuracy: 0.7245 - val_loss: 0.5740
# Epoch 95/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7399 - loss: 0.5313 - val_accuracy: 0.7246 - val_loss: 0.5766
# Epoch 96/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7401 - loss: 0.5352 - val_accuracy: 0.7242 - val_loss: 0.5823
# Epoch 97/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7434 - loss: 0.5299 - val_accuracy: 0.7243 - val_loss: 0.5794
# Epoch 98/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7459 - loss: 0.5260 - val_accuracy: 0.7248 - val_loss: 0.5819
# Epoch 99/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7438 - loss: 0.5275 - val_accuracy: 0.7229 - val_loss: 0.5774
# Epoch 100/100
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7410 - loss: 0.5310 - val_accuracy: 0.7248 - val_loss: 0.5768

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 0s - 2ms/step - accuracy: 0.7248 - loss: 0.5768
# Loss: 0.5768307447433472, Accuracy: 0.724781334400177

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
